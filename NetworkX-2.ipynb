# %% [markdown]
# In this exercise we will modell the road network in india

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ### Undirected graph

# %%
undi = nx.Graph()

# %% [markdown]
# ### Directed graph

# %%
dir = nx.DiGraph()

# %%
cities = ["Delhi","Banglore","Hyderabad","Ahmedabad","Chennai","Kolkata","Surat","Pune","Jaipur"]

# %%
for city in cities:
    undi.add_node(city)

nx.draw(undi,with_labels=1)
plt.show()

# %%
costs = []
value = 100
while(value <= 2000):
    costs.append(value)
    value = value + 100
print(costs)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000]

# %%
import random
print(undi)
while(undi.number_of_edges()<16):
    c1 = random.choice(undi.nodes())
    c2 = random.choice(undi.nodes())
    if c1 != c2 and undi.has_edge(c1,c2)==0:
        w = random.choice(costs)
        undi.add_edge(c1,c2,weight=w)
pos = nx.spring_layout(G)
nx.draw(undi,pos)
plt.show()
# Out:
# Graph with 9 nodes and 0 edges
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 4
#       2 print(undi)
#       3 while(undi.number_of_edges()<16):
# ----> 4     c1 = random.choice(undi.nodes())
#       5     c2 = random.choice(undi.nodes())
#       6     if c1 != c2 and undi.has_edge(c1,c2)==0:
#
# File C:\Program Files\Python312\Lib\random.py:348, in Random.choice(self, seq)
#     346 if not len(seq):
#     347     raise IndexError('Cannot choose from an empty sequence')
# --> 348 return seq[self._randbelow(len(seq))]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\networkx\classes\reportviews.py:194, in NodeView.__getitem__(self, n)
#     189 if isinstance(n, slice):
#     190     raise nx.NetworkXError(
#     191         f"{type(self).__name__} does not support slicing, "
#     192         f"try list(G.nodes)[{n.start}:{n.stop}:{n.step}]"
# ...
